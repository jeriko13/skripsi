# %%
from google.colab import drive #Import Data dari google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/skripsi/dataset/curah-hujan.csv')
print(df)
df.head(1000)
# Out:
#     curah_hujan
# 0           1.0
# 0          12.0
# 0           2.0
# 0          16.0
# 0          14.0
# ..          ...
# 0           4.0
# 0           1.0
# 0           NaN
# 0           NaN
# 0           NaN
#
# [1286 rows x 1 columns]
#     curah_hujan
# 0           1.0
# 0          12.0
# 0           2.0
# 0          16.0
# 0          14.0
# ..          ...
# 0           NaN
# 0           NaN
# 0           NaN
# 0           NaN
# 0           NaN
#
# [1000 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/skripsi/dataset/data.csv')
print(df)
df.head(10)
# Out:
#                Tanggal;total_precipitation
# Jan 1 2017;0                             1
# Jan 2 2017;0                            12
# Jan 3 2017;0                             2
# Jan 4 2017;0                            16
# Jan 5 2017;0                            14
# Jan 6 2017;0                             2
# Jan 7 2017;0                             3
# Jan 8 2017;0                             3
# Jan 9 2017;0                            18
# Jan 10 2017;0                           12
# Jan 11 2017;0                            5
# Jan 12 2017;0                            2
# Jan 13 2017;0                            4
# Jan 14 2017;0                           21
# Jan 15 2017;0                            1
# Jan 16 2017;0                            8
# Jan 17 2017;0                            6
# Jan 18 2017;0                            6
# Jan 19 2017;0                           12
# Jan 20 2017;0                            7
# Jan 21 2017;0                           12
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
df['prediksi'] = df.iloc[:,0].rolling(window=3).mean()
df.head(10)
# Out:
#                Tanggal;total_precipitation   prediksi
# Jan 1 2017;0                             1        NaN
# Jan 2 2017;0                            12        NaN
# Jan 3 2017;0                             2   5.000000
# Jan 4 2017;0                            16  10.000000
# Jan 5 2017;0                            14  10.666667
# Jan 6 2017;0                             2  10.666667
# Jan 7 2017;0                             3   6.333333
# Jan 8 2017;0                             3   2.666667
# Jan 9 2017;0                            18   8.000000
# Jan 10 2017;0                           12  11.000000

# %%
df['prediksi'] = df['prediksi'].replace(np.nan,0)
df.head()
# Out:
#               Tanggal;total_precipitation   prediksi
# Jan 1 2017;0                            1   0.000000
# Jan 2 2017;0                           12   0.000000
# Jan 3 2017;0                            2   5.000000
# Jan 4 2017;0                           16  10.000000
# Jan 5 2017;0                           14  10.666667

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error (df['prediksi'], df['Tanggal;total_precipitation'])
rmse=np.sqrt(mse)
print ("MSE: ",mse)
print ("RMSE: ",rmse)
# Out:
# MSE:  27.3639846743295
# RMSE:  5.231059612958879

# %%
a=range(len(df))
plt.scatter(a,df['Tanggal;total_precipitation'], color = 'blue')
plt.plot(a,df['prediksi'], color = 'green')
plt.title('Curah Hujan di Brebes')
plt.xlabel('Data ke-')
plt.ylabel('Curah Hujan')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/skripsi/dataset/curah-hujan.csv')
print(df)
df.head(10)
# Out:
#     curah_hujan
# 0           1.0
# 0          12.0
# 0           2.0
# 0          16.0
# 0          14.0
# ..          ...
# 0           4.0
# 0           1.0
# 0           NaN
# 0           NaN
# 0           NaN
#
# [1286 rows x 1 columns]
#    curah_hujan
# 0          1.0
# 0         12.0
# 0          2.0
# 0         16.0
# 0         14.0
# 0          2.0
# 0          3.0
# 0          3.0
# 0         18.0
# 0         12.0

# %%
import numpy as np
import matplotlib.pyplot as plt
df['prediksi'] = df.iloc[:,0].rolling(window=3).mean()
df.head(10)
# Out:
#    curah_hujan   prediksi
# 0          1.0        NaN
# 0         12.0        NaN
# 0          2.0   5.000000
# 0         16.0  10.000000
# 0         14.0  10.666667
# 0          2.0  10.666667
# 0          3.0   6.333333
# 0          3.0   2.666667
# 0         18.0   8.000000
# 0         12.0  11.000000

# %%
df['prediksi'] = df['prediksi'].replace(np.nan,0)
df.head(100)
# Out:
#     curah_hujan   prediksi
# 0           1.0   0.000000
# 0          12.0   0.000000
# 0           2.0   5.000000
# 0          16.0  10.000000
# 0          14.0  10.666667
# ..          ...        ...
# 0           1.0   1.666667
# 0           8.0   3.333333
# 0           5.0   4.666667
# 0           8.0   7.000000
# 0           5.0   6.000000
#
# [100 rows x 2 columns]

# %%
import pandas as pd
import numpy as np

def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
    Test_y = np.nan_to_num(Test_y)

# %%
df.isnull().any().any()  
df.isnull().any()
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.fillna(999, inplace=True)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error (df['prediksi'], df['curah_hujan'])
rmse=np.sqrt(mse)
print ("MSE: ",mse)
print ("RMSE: ",rmse)
# Out:
# MSE:  122797.63435285987
# RMSE:  350.4249339771071

# %%
a=range(len(df))
plt.scatter(a,df['curah_hujan'], color = 'red')
plt.plot(a,df['prediksi'], color = 'navy')
plt.title('Curah Hujan di Brebes')
plt.xlabel('Data ke-')
plt.ylabel('Curah Hujan')
plt.show()

# %%
a=range(len(df))
plt.scatter(a,df['curah_hujan'], color = 'orange')
plt.plot(a,df['prediksi'], color = 'navy')
plt .xticks (rotation= 45 ) 
plt .xlabel ('Date',size= 15 ) 
plt .ylabel ('Curah Hujan ',size= 15 ) 
plt .title ('Data Aktual dan Prediksi Curah Hujan di Brebes',size= 15 ) 
plt .show ()
